# %%
pip install pyautogui
# Out:
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.53.tar.gz (59 kB)
#      |████████████████████████████████| 59 kB 1.1 MB/s eta 0:00:01
# Collecting pymsgbox
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting PyTweening>=1.0.1
#   Downloading pytweening-1.0.4.tar.gz (14 kB)
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.28.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting pygetwindow>=0.0.5
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
# Collecting mouseinfo
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
# Requirement already satisfied: pyobjc-core in /opt/anaconda3/lib/python3.8/site-packages (from pyautogui) (8.1)
# Requirement already satisfied: pyobjc in /opt/anaconda3/lib/python3.8/site-packages (from pyautogui) (8.1)
# Collecting pyrect
#   Downloading PyRect-0.1.4.tar.gz (15 kB)
# Requirement already satisfied: Pillow>=6.2.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyscreeze>=0.1.21->pyautogui) (8.2.0)
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Collecting rubicon-objc
#   Downloading rubicon_objc-0.4.2-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 2.3 MB/s eta 0:00:01
# Requirement already satisfied: pyobjc-framework-Photos==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Accounts==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-AdServices==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Quartz==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreML==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Network==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-EventKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Security==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-OSLog==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-NetFS==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-MailKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreText==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CallKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Automator==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-PushKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-MapKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Intents==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-PassKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-WebKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Vision==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Speech==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreData==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-AVKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Contacts==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Metal==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Social==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-GameKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-GameController==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==8.1 in /opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui) (8.1)
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, PyTweening, mouseinfo, pymsgbox, pyperclip, pyrect
#   Building wheel for pyautogui (setup.py) ... done
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36583 sha256=145346b072ff69f38388c366f6e16c99bd384d8a633834c125d5a21873acda87
#   Stored in directory: /Users/abhishekmathur/Library/Caches/pip/wheels/54/04/f7/55704a9d374ed923785a4fdc0ef00151fa25306b3b93345532
#   Building wheel for pygetwindow (setup.py) ... done
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11078 sha256=c678e2a9ad51067b9e304cff480b22c27d0a0b17295887299c4d5238cb1ea17c
#   Stored in directory: /Users/abhishekmathur/Library/Caches/pip/wheels/91/e3/04/184bda98ec7f7d5f0ba1f372bcf7b3ba86325151ae1dd690fe
#   Building wheel for pyscreeze (PEP 517) ... done
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.28-py3-none-any.whl size=13023 sha256=3bd75e24d3255a18820d896ec418e549d46d23319a524ce150d62a53ec1d75c6
#   Stored in directory: /Users/abhishekmathur/Library/Caches/pip/wheels/b1/b0/5c/9fb5beb2d6c708479a670e92f4ab3b54523a15c9cd4a46e24e
#   Building wheel for PyTweening (setup.py) ... done
#   Created wheel for PyTweening: filename=pytweening-1.0.4-py3-none-any.whl size=5825 sha256=cb911bc329ee8b864add460d48052d88ebf850cc8685401d7b1aa6b3f8a0625b
#   Stored in directory: /Users/abhishekmathur/Library/Caches/pip/wheels/a2/1b/69/dc477653ccc19228bf53af76c623e4e82e5dc1b6f78d5c4d35
#   Building wheel for mouseinfo (setup.py) ... done
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10905 sha256=603dfea7f344508855b2c20a1f2cd07b43db8d3d0a7be7664aaa64c708f4bdbb
#   Stored in directory: /Users/abhishekmathur/Library/Caches/pip/wheels/d1/72/fb/35f403de66285df8ecca7049bcc61bfb57aba0f76d1f08f7eb
#   Building wheel for pymsgbox (PEP 517) ... done
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7420 sha256=71a60788ad7fb60fb581f3abf0a2d476ab1565d75286a4cfa0d0645fef0f8415
#   Stored in directory: /Users/abhishekmathur/Library/Caches/pip/wheels/91/28/0d/f4eb606d38276836237d6dc2abf094241e6db5682a126e0389
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11107 sha256=aeabc877db6797833c03add197267d878a9ecc96f2d4b383396be59cc6ce63b4
#   Stored in directory: /Users/abhishekmathur/Library/Caches/pip/wheels/7f/1a/65/84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
#   Building wheel for pyrect (setup.py) ... done
#   Created wheel for pyrect: filename=PyRect-0.1.4-py2.py3-none-any.whl size=9547 sha256=621cdc6a466f5e949dfe4ce05ba51ecf5bb140e6aa9d703413f334c5ce1c5b52
#   Stored in directory: /Users/abhishekmathur/Library/Caches/pip/wheels/d1/e4/47/c62f8291b16b6df7e89ac885881ff71f35ca04c6e384251de9
# Successfully built pyautogui pygetwindow pyscreeze PyTweening mouseinfo pymsgbox pyperclip pyrect
# Installing collected packages: rubicon-objc, pyrect, pyperclip, PyTweening, pyscreeze, pymsgbox, pygetwindow, mouseinfo, pyautogui
# Successfully installed PyTweening-1.0.4 mouseinfo-0.1.3 pyautogui-0.9.53 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.1.4 pyscreeze-0.1.28 rubicon-objc-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.8/site-packages (8.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from numpy import asarray

# %%
import pyautogui # pip install pyautogui
from PIL import Image, ImageGrab # pip install pillow
# from numpy import asarray
import time

# %%
def hit(key):
    pyautogui.keyDown(key)
    return

def isCollide(data):
    # Draw the rectangle for birds
    for i in range(300, 415):
        for j in range(410, 563):
            if data[i, j] < 100:
                hit("down")
                return

    for i in range(300, 415):
        for j in range(563, 650):
            if data[i, j] < 100:
                hit("up")
                return
    return

if __name__ == "__main__":
    print("Hey.. Dino game about to start in 3 seconds")
    time.sleep(2)
    # hit('up') 

    while True:
        image = ImageGrab.grab().convert('L')  
        data = image.load()
        isCollide(data)
            
        # print(asarray(image))
        '''
        # Draw the rectangle for cactus
        for i in range(275, 325):
            for j in range(563, 650):
                data[i, j] = 0
        
        # Draw the rectangle for birds
        for i in range(250, 300):
            for j in range(410, 563):
                data[i, j] = 171

        image.show()
        break
      '''
